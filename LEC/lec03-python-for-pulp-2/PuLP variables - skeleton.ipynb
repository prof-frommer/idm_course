# %% [markdown]
# ## PuLP Variables

# %%
from pulp import *

# %% [markdown]
# Recall before we created PuLP LP variables one at a time using:
#
#     x1 = LpVariable('AquaSpas',lowBound=0)

# %%
# YOUR CODE HERE

print(x1)

# %% [markdown]
# Alternatively, we can **create a dictionary's-worth of them** at a time using PuLP's `LpVariable.dicts` method.

# %%
fruits = {'apples','oranges','pears'}

# %%
# YOUR CODE HERE

print(x)

# %% [markdown]
# **Do:** Explain what happened above.
#
#
#
#
# How can we create a collection of variables like this:
#
#     y_0, y_1, y_2, ..., y_9
#
# using the syntax above?

# %%
# YOUR CODE HERE

print(y)

# %% [markdown]
# **Let's create objective coefficients for our fruit variables.**

# %%
# YOUR CODE HERE

print('objective coefficients:  ',obj_coeffs)

# %% [markdown]
# ### An important PuLP concept - constructing an objective function.
#
# We use the `lpSum` command in PuLP.  It can accept a **comprehension** as input.
#
# Recall we already have lists of variables and objective coefficients in `obj_coeffs` and `x`.

# %%
# YOUR CODE HERE

print('objective function: ',obj)

# %% [markdown]
# ### The **value** function.

# %%
# Let's see the value of the objective
# YOUR CODE HERE

# %%
# Nothing happened.  The reason is the variable values are all "None" so the objective value is "None".
value(obj) == None

# %%
value(x['oranges']) == None

# %% [markdown]
# Just for fun, let's set some variable values (normally PuLP does this when solving).
# To do this we will use the `varValue` method.

# %%
# YOUR CODE HERE

# %%
# Check the values
[x[i].varValue for i in x.keys()]

# %% [markdown]
# Here's another way to look - inside the variable's `__dict__` dictionary of properties.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### See the variable's value (`varValue`) of 3 inside?

# %% [markdown]
# Now that the variable values have been defined, let's go back and check the objective value.  Recall the objective was:
#
#     7*x_apples + 4*x_oranges + x_pears
#
# and we set the variable values to 6, 3, and 1, respectively.

# %%
# YOUR CODE HERE
